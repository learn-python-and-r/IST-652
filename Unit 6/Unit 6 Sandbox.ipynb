# %% [markdown]
# # Review: Quiz 1

# %% [markdown]
# Question 1: Lists and Strings
#
# Suppose that you have a list of strings named examples. Write a Python loop that goes through the list and prints each string where the string length is three or more and the first and last characters of the strings are the same.
#
# Test your code on the following three versions of the list examples:
# * examples = ['abab', 'xyz', 'aa', 'x', 'bcb']
# * examples = ['', 'x', 'xy', 'xyx', 'xx']
# * examples = ['aaa', 'be', 'abc', 'hello']
#
# You may do this exercise either in the interpreter or in a program. Please submit your code and the output from the three examples.

# %%
import re 

#examples = ['aaa', 'be', 'abc', 'hello']
#examples = ['', 'x', 'xy', 'xyx', 'xx']
examples = ['aaa', 'be', 'abc', 'hello']

for example in examples:
    stringlength = len(example) # length of the string
    try:
        firstchar = example[0] # 
        lastchar = example[stringlength-1]
    
        if stringlength >= 3 and firstchar == lastchar:
            print(example)
    except IndexError:
        continue
# Out:
# aaa

# %%
examples = ['aaa', 'be', 'abc', 'hello']

for i in range(0,len(examples)+1):
    try:
        print(examples[i])
    except IndexError:
        print('ERROR: Your index is out of bounds.')
    except ValueError:
        print('ERROR: There is a value error.')
# Out:
# aaa
# be
# abc
# hello
# ERROR: Your index is out of bounds.

# %% [markdown]
# Question 2: Reading and processing data in a file
#
# For this question, you are to write a program that reads the data in the file state_satscores_2004.txt. Each line of this file has name of a state, mean Verbal SAT score, and mean Math SAT score.
#
# After reading the data,
#
# * a. Print the state with the highest mean Verbal SAT score
# * b. Print each state that has a mean Math SAT score greater than 500
#
# Submit the code and the output from your program.
#
# You may use the code developed for the NBA data as a template, but it is absolutely essential that you use appropriate variable names and that you write original comments for what your program does.
#
# If you prefer, you can write this program with a csv reader, using state_satscores_2004.tsv.

# %%
import os 

os.chdir('/Users/jason/Downloads/')

# Courtesy of Pierre 
import pandas as pd

scores = pd.read_csv('state_satscores_2004.tsv',sep="\t",header=None)

scores.columns = ['State','Mean_Verbal','Mean_Math', 'delete']
scores = scores.drop(columns='delete',axis=1)
scores = scores.set_index('State')
scores.sort_values(by='Mean_Verbal',ascending=False).head(1)
# Out:
#               Mean_Verbal  Mean_Math
# State
# South Dakota          594        597

# %%
highMath = scores[scores['Mean_Math'] > 500]
highMath
# Out:
#                 Mean_Verbal  Mean_Math
# State
# New York                497        510
# Connecticut             515        515
# Massachusetts           518        523
# New Jersey              501        514
# New Hampshire           522        521
# Maine                   505        501
# Pennsylvania            501        502
# Rhode Island            503        502
# Virginia                515        509
# North Carolina          499        507
# Maryland                511        515
# Vermont                 516        512
# Indiana                 501        506
# Hawaii                  487        514
# Oregon                  527        528
# Alaska                  518        514
# Washington              528        531
# California              501        519
# Nevada                  507        514
# Arizona                 523        524
# Montana                 537        539
# Ohio                    538        542
# Colorado                554        553
# Idaho                   540        539
# West Virginia           524        514
# Tennessee               567        557
# New Mexico              554        543
# Kentucky                559        557
# Wyoming                 551        546
# Michigan                563        573
# Illinois                585        597
# Minnesota               587        593
# Alabama                 560        553
# Kansas                  584        585
# Louisiana               564        561
# Missouri                587        585
# Nebraska                569        576
# Oklahoma                569        566
# Wisconsin               587        596
# Utah                    565        556
# Arkansas                569        555
# Iowa                    593        602
# South Dakota            594        597
# Mississippi             562        547
# North Dakota            582        601

# %%
# Alternative solution (courtesy of Shawn Anderson)
import os

os.chdir('/Users/jason/Downloads')

satfile = open ('state_satscores_2004.txt', 'r')
# reset count for printing line numbers
satlist = [ ]
T500 = []
for line in satfile:
    textline = line.strip()
    # split the line on whitespace
    items = textline.split()
    # add the list of items to the NBAlist
    satlist.append(items)
    #sort on the second element
    satsort = sorted(satlist, key=lambda item:item[1])
#print the last element - being the highest Verbal
    if int(items[2]) >= int(500):
        T500.append(items)#print(items)
        #satlist[1][2])
print(satsort[-1][0],'holds the highest Verbal SAT score,',satsort[-1][1],'\n')
T500 = sorted(T500, key=lambda item:item[2])

print('\n',T500)
satfile.close()
# Out:
# South_Dakota holds the highest Verbal SAT score, 594
#
#
#  [['Maine', '505', '501'], ['Pennsylvania', '501', '502'], ['Rhode_Island', '503', '502'], ['Indiana', '501', '506'], ['North_Carolina', '499', '507'], ['Virginia', '515', '509'], ['\ufeffNew_York', '497', '510'], ['Vermont', '516', '512'], ['New_Jersey', '501', '514'], ['Hawaii', '487', '514'], ['Alaska', '518', '514'], ['Nevada', '507', '514'], ['West_Virginia', '524', '514'], ['Connecticut', '515', '515'], ['Maryland', '511', '515'], ['California', '501', '519'], ['New_Hampshire', '522', '521'], ['Massachusetts', '518', '523'], ['Arizona', '523', '524'], ['Oregon', '527', '528'], ['Washington', '528', '531'], ['Montana', '537', '539'], ['Idaho', '540', '539'], ['Ohio', '538', '542'], ['New_Mexico', '554', '543'], ['Wyoming', '551', '546'], ['Mississippi', '562', '547'], ['Colorado', '554', '553'], ['Alabama', '560', '553'], ['Arkansas', '569', '555'], ['Utah', '565', '556'], ['Tennessee', '567', '557'], ['Kentucky', '559', '557'], ['Louisiana', '564', '561'], ['Oklahoma', '569', '566'], ['Michigan', '563', '573'], ['Nebraska', '569', '576'], ['Kansas', '584', '585'], ['Missouri', '587', '585'], ['Minnesota', '587', '593'], ['Wisconsin', '587', '596'], ['Illinois', '585', '597'], ['South_Dakota', '594', '597'], ['North_Dakota', '582', '601'], ['Iowa', '593', '602']]

# %% [markdown]
# # Review: handling data in pandas

# %% [markdown]
# Repeat the activity that we just went through in the lecture to read the data from the provided State Data. Transform the data.
#
# state_data = {'State':['Alabama','Alaska','Arizona','Arkansas'],'PostCode':['AL','AK','AZ','AR'],'Area':['52,423','656,424','*','53,182'],'Pop':['4,040,587','550,043','3,665,228','2,350,750']}
#
# Create a dataframe using pd.DataFrame(state_data, columns=['State','PostCode','Area','Pop'].
#
# Display the table.
#
# Index the table by 'State'.
#
# Replace the '*' with '0'.
#
# Define a function to replace ',' with ''.
#
# Use this function to replace the commas in 'Area' and 'Pop'.
#
# Submit your code and a final display of your table.

# %%
# Courtesy of Jennifer Mead
import numpy as np
import pandas as pd

state_data = {'State':['Alabama','Alaska','Arizona','Arkansas'],
              'PostCode':['AL','AK','AZ','AR'],
              'Area':['52,423','656,424','*','53,182'],
              'Pop':['4,040,587','550,043','3,665,228','2,350,750']
             }
# Out:
# 'Alaska'

# %%
# 1 and 2
state_df = pd.DataFrame(state_data, 
                        columns = ['State', 'PostCode', 'Area', 'Pop'])
state_df

# %%
# 3
state_df['State']

# %%
# 4
state_df = state_df.replace('*','0')
state_df

# %%
# 5
def rid_commas(string_to_change):
    return string_to_change.replace(',','')

# %%
# 6
state_df['Pop'] = state_df['Pop'].map(rid_commas)
state_df['Area'] = state_df['Area'].map(rid_commas)
state_df

# %% [markdown]
# # HTML Exercise: Courtesy of Brad Coy

# %%
# Obtain HTML data via urllib
from urllib import request

# Set the URL to scrape
syrurl = "https://news.syr.edu/blog/2019/07/24/light-work-awarded-100000-grant-from-the-andy-warhol-foundation-for-the-visual-arts/"

## Open, read, and decode the URL
response = request.urlopen(syrurl).read().decode('utf8')

# Check the type of the response variable
print('The response type is:', type(response), '\n')

# Print the first 500 characters of the response
print('The beginning of the response is:', '\n', response[:500])
# Out:
# The response type is: <class 'str'>
#
# The beginning of the response is:
#  <!DOCTYPE html>
# <html lang="en-US">
# <head>
# 	<!-- meta -->
# 		<meta charset="UTF-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=yes" />
# 		<!-- type -->
# 			<meta name="twitter:card" content="summary" />
# 			<meta property="og:type" content="article"/>
# 		<!-- site -->
# 			<meta name="twitter:site" content="@SyracuseUNews" />
# 			<meta property="og:site_name" content="SU News"/>
# 		<!-- title -->
# 			<meta name="twitter:title" content="Light Work Awarded $100,0

# %%
# Parse the HTML response via beautiful soup

from bs4 import BeautifulSoup

# Parse the response variable
parsed = BeautifulSoup(response, 'html.parser')

# Check the type of the parsed variable
print('The new object type is:', type(parsed), '\n')

# Title of the webpage
print('The title of the webpage is:', parsed.title.get_text(), '\n')

# Print the first 10 tags
print('The first ten tags are:', parsed.find_all('a')[:10])
# Out:
# The new object type is: <class 'bs4.BeautifulSoup'>
#
# The title of the webpage is: Light Work Awarded $100,000 Grant from the Andy Warhol Foundation for the Visual Arts | Syracuse University News
#
# The first ten tags are: [<a class="skip-link screen-reader-text" href="#entry-title">Skip to main content</a>, <a href="https://news.syr.edu/" title="Home">Home</a>, <a href="https://news.syr.edu/about/" title="About">About</a>, <a href="https://news.syr.edu/faculty-experts/" title="Faculty Experts">Faculty Experts</a>, <a href="https://news.syr.edu/for-the-media/" title="For The Media">For The Media</a>, <a href="https://news.syr.edu/videos/" title="Videos">Videos</a>, <a href="https://news.syr.edu/topics/" title="Topics">Topics</a>, <a href="https://news.syr.edu/topics/alumni/" title="Alumni">Alumni</a>, <a href="https://news.syr.edu/topics/events/">Events</a>, <a href="https://news.syr.edu/topics/faculty/" title="Faculty">Faculty</a>]

# %%
# Check the type of the parsed variable
print('The new object type is:', type(parsed), '\n')
# Out:
# The new object type is: <class 'bs4.BeautifulSoup'>

# %%
# Title of the webpage
print('The title of the webpage is:', parsed.title.get_text(), '\n')
# Out:
# The title of the webpage is: Light Work Awarded $100,000 Grant from the Andy Warhol Foundation for the Visual Arts | Syracuse University News

# %%
# Print the first 10 tags
print('The first ten tags are:', parsed.find_all('a')[0:100])
# Out:
# The first ten tags are: [<a class="skip-link screen-reader-text" href="#entry-title">Skip to main content</a>, <a href="https://news.syr.edu/" title="Home">Home</a>, <a href="https://news.syr.edu/about/" title="About">About</a>, <a href="https://news.syr.edu/faculty-experts/" title="Faculty Experts">Faculty Experts</a>, <a href="https://news.syr.edu/for-the-media/" title="For The Media">For The Media</a>, <a href="https://news.syr.edu/videos/" title="Videos">Videos</a>, <a href="https://news.syr.edu/topics/" title="Topics">Topics</a>, <a href="https://news.syr.edu/topics/alumni/" title="Alumni">Alumni</a>, <a href="https://news.syr.edu/topics/events/">Events</a>, <a href="https://news.syr.edu/topics/faculty/" title="Faculty">Faculty</a>, <a href="https://news.syr.edu/topics/library/">Library</a>, <a href="https://news.syr.edu/topics/research/" title="Research">Research</a>, <a href="https://news.syr.edu/topics/students/">Students</a>, <a href="https://news.syr.edu/topics/" title="All Topics">All Topics</a>, <a href="https://news.syr.edu/contact/" title="Contact">Contact</a>, <a href="https://news.syr.edu/submit/" title="Submit">Submit</a>, <a aria-label="Search toggle" class="search-toggle icon search" href="#" role="search"></a>, <a href="http://www.syracuse.edu" title="Syracuse University"></a>, <a href="https://news.syr.edu/" rel="home" title="Syracuse University News"></a>, <a href="/section/arts-culture">
# <img alt="Arts &amp; Culture" src="https://news.syr.edu/wp-content/themes/su-news/lib/img/arts-culture.png" title="Arts &amp; Culture"/>
# </a>, <a href="https://news.syr.edu/sections/" title="All News">All News</a>, <a href="https://news.syr.edu/section/arts-culture/" title="Arts &amp; Culture">Arts &amp; Culture</a>, <a href="https://news.syr.edu/section/business-economy/" title="Business &amp; Economy">Business &amp; Economy</a>, <a href="https://news.syr.edu/section/campus-community/" title="Campus &amp; Community">Campus &amp; Community</a>, <a href="https://news.syr.edu/section/health-society/" title="Health &amp; Society">Health &amp; Society</a>, <a href="https://news.syr.edu/section/media-law-policy/" title="Media, Law &amp; Policy">Media, Law &amp; Policy</a>, <a href="https://news.syr.edu/section/stem/" title="STEM">STEM</a>, <a href="https://news.syr.edu/section/veterans/" title="Veterans Affairs">Veterans</a>, <a>|</a>, <a href="https://cusecommunity.syr.edu/s/1632/17/interior.aspx?sid=1632&amp;gid=2&amp;pgid=2223">Alumni</a>, <a href="https://news.syr.edu/the-peel/">The Peel</a>, <a href="http://www.cuse.com/" rel="noopener noreferrer" target="_blank">Athletics</a>, <a aria-expanded="false" class="mobile-menu-toggle js-mobile-menu-open" href="#" role="button"><span></span><span></span><span></span></a>, <a aria-expanded="
%%
# -*- coding: utf-8 -*-
"""
Created on Mon Feb  3 20:41:18 2020

@author: MrAndMrsKeith
"""

from urllib import request
superbowlurl = "https://www.wralsportsfan.com/after-super-bowl-win-chiefs-already-eyeing-repeat-next-year/18927591/"
# response = request.urlopen(superbowlurl)
# print(type(response))

# #If we just read the response, we get a sequence of bytes, so instead we decode it to convert it to a Python string.
# html = response.read().decode('utf8')
# print(type(html))

html = request.urlopen(superbowlurl).read().decode('utf8')

print(html[:500])
# Out:
# <!doctype html>
# <!--[if IE 8]>       <html lang="en" xml:lang="en" class="no-js lt-ie9 site-wralsportsfan sports"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="en" xml:lang="en" class="no-js site-wralsportsfan sports"> <!--<![endif]-->
#
# <head>
#     <meta charset="utf-8">
#     <title>After Super Bowl win, Chiefs already eyeing repeat next year :: WRALSportsFan.com</title>
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#
#
# <link rel="preconnect" href="//fonts.googl

# %% [markdown]
# BeautifulSoup
# The Python package BeautifulSoup will parse the HTML document to find its structure, fixing any non-well-formed tag structure as best it can.
# http://www.crummy.com/software/BeautifulSoup/bs4/doc/
# [An alternate package sometimes used is lxml.]
# The typical use is to use the BeautifulSoup parser on an HTML document to get a soup object:

# %%
from bs4 import BeautifulSoup
htmlsoup = BeautifulSoup(html, 'html.parser')
print(type(htmlsoup))

#A BeautifulSoup object corresponds to a tag. Every tag has a name, (possibly) some attributes, a value, and (possibly) some children. When you have a tag, you can get information about that as a node in the tree structure generated by the tags of the document. You can then navigate anything below that tag in the tree, either by looking for specific tags or by following the children.
#So every tag and tag structure can be found from the object that we obtained from the parser. If you give the name of a tag, it will find the first instance of that tag.
firsttitle = htmlsoup.title
print(firsttitle)
print(type(firsttitle))
print(firsttitle.name)
#Use the get_text() function to get the actual tag content:
print(firsttitle.get_text())
# Out:
# <class 'bs4.BeautifulSoup'>
# <title>After Super Bowl win, Chiefs already eyeing repeat next year :: WRALSportsFan.com</title>
# <class 'bs4.element.Tag'>
# title
# After Super Bowl win, Chiefs already eyeing repeat next year :: WRALSportsFan.com

# %% [markdown]
# # Finding Anchor tags
#
# We can also use the find_all() function to return a ResultSet of all the instances of that tag:

# %%
anchors = htmlsoup.find_all('a')
print(type(anchors))
print(len(anchors))

print(anchors[:8])

#For each anchor, â€˜aâ€™ tag, we use the â€˜hrefâ€™ attribute to get the actual anchor part, where I converted the result to an actual string:
links = [str(link.get('href')) for link in htmlsoup.find_all('a')]
print(links[ :10])

outlinks = [link for link in links if link.startswith('http')]
outlinks

#print(len(outlinks))
#print(outlinks[:10])
# Out:
# <class 'bs4.element.ResultSet'>
# 618
# [<a class="skip-link" href="#g-wrap-main">skip to main content</a>, <a class="go-back" href="https://www.wral.com/">
# <span class="icon icon-ico-arrow-l"></span>
# <span class="go-back-text">WRAL.com</span>
#  'https://www.wral.com/nc-pup-nominated-for-puppy-bowl-decides-to-nap-instead/18921656/',
#  'https://www.wral.com/durham-based-mckinney-delivers-super-bowl-ad-for-little-caesars/18921679/',
#  'https://www.wral.com/durham-based-mckinney-delivers-super-bowl-ad-for-little-caesars/18921679/',
#  'https://www.wral.com/charlotte-not-thrilled-to-be-included-in-super-bowl-ad/18915674/',
#  'https://www.wral.com/charlotte-not-thrilled-to-be-included-in-super-bowl-ad/18915674/',
#  'http://pubads.g.doubleclick.net/gampad/clk?id=132236299&iu=/6167',
#  'http://pubads.g.doubleclick.net/gampad/clk?id=5262781185&iu=/6167',
#  'http://pubads.g.doubleclick.net/gampad/clk?id=5261049005&iu=/6167',
#  'http://pubads.g.doubleclick.net/gampad/clk?id=132236179&iu=/6167',
#  'http://pubads.g.doubleclick.net/gampad/clk?id=132016219&iu=/6167',
#  'https://v7player.wostreaming.net/7318',
#  'https://v7player.wostreaming.net/7319',
#  'https://v7player.wostreaming.net/7317',
#  'http://www.wralsportsfan.com/sportsradio/page/14766290/',
#  'https://www.twitter.com/mr_sheltonius',
#  'https://twitter.com/NASCARonNBC',
#  'https://twitter.com/search/%23Daytona500',
#  'https://twitter.com/nascar',
#  'https://t.co/D9qlsKkqcp',
#  'https://www.twitter.com/mr_sheltonius',
#  'https://twitter.com/NASCARONFOX',
#  'https://t.co/4QPEQQoTjS',
#  'https://www.twitter.com/highschoolot',
#  'https://twitter.com/ZackAdamsHSOT',
#  'https://twitter.com/SouthWestGHS',
#  'https://twitter.com/search/%23PTC',
#  'https://twitter.com/Du',
#  'https://www.twitter.com/lebrownlow',
#  'https://t.co/jCZIB3oD9N',
#  'https://www.twitter.com/highschoolot',
#  'https://twitter.com/CPacanovskyHSOT',
#  'https://twitter.com/search/%23HSOTscores',
#  'https://www.twitter.com/JFiWRAL',
#  'https://t.co/Pof37y3Hu5',
#  'https://www.twitter.com/999TheFan',
#  'https://t.co/2XZSU96MKn',
#  'https://www.twitter.com/highschoolot',
#  'https://twitter.com/CPacanovskyHSOT',
#  'https://twitter.com/search/%23HSOTscores',
#  'https://www.twitter.com/joshwgoodson',
#  'https://twitter.com/search/%23DAYTONA500',
#  'https://www.twitter.com/AGoldFan',
#  'https://twitter.com/search/%23HeadbandMonday',
#  'https://t.co/w8rYyFABwG',
#  'https://www.twitter.com/joeovies',
#  'https://t.co/3mCq3kMhvW',
#  'https://www.twitter.com/highschoolot',
#  'https://twitter.com/CPacanovskyHSOT',
#  'https://twitter.com/search/%23HSOTscores',
#  'https://www.twitter.com/999TheFan',
#  'https://twitter.com/AGoldFan',
#  'https://twitter.com/joeovies',
#  'https://twitter.com/search/%23NCStatevsBC',
#  'https://twitter.com/search/%23StadiumSeries',
#  'https://twitter.com/TDCanes',
#  'https://t.co/92KaxKhWaB',
#  'https://www.twitter.com/highschoolot',
#  'https://twitter.com/CPacanovskyHSOT',
#  'https://twitter.com/search/%23HSOTscores',
#  'https://www.twitter.com/Mary_Dunleavy',
#  'https://twitter.com/UNC_Basketball',
#  'https://twitter.com/search/%23CarolinaFamily',
#  'https://www.twitter.com/DurhamBulls',
#  'https://t.co/tg7b2VWQdE',
#  'https://www.twitter.com/WXMoose',
#  'https://t.co/3dfFBVUstP',
#  'https://www.twitter.com/999TheFan',
#  'https://twitter.com/katcampbellwx',
#  'https://twitter.com/wralweather',
#  'https://www.twitter.com/joeovies',
#  'https://t.co/4M5cg7ltqn',
#  'https://www.twitter.com/WRALSportsFan',
#  'https://t.co/dQ9trv7wF7',
#  'https://www.twitter.com/WRALSportsFan',
#  'https://t.co/4SjhR9QyUu',
#  'https://www.twitter.com/WRALSportsFan',
#  'https://t.co/K3Z2E2svdI',
#  'https://www.twitter.com/WRALSportsFan',
#  'https://t.co/FMaghmY0FY',
#  'https://www.twitter.com/WRALSportsFan',
#  'https://twitter.com/joeovies',
#  'https://twitter.com/lebrownlow',
#  'https://www.twitter.com/WRALSportsFan',
#  'https://t.co/NFADOp9HTF',
#  'https://www.twitter.com/WRALSportsFan',
#  'https://t.co/OziwwvOTTJ',
#  'https://www.twitter.com/WRALSportsFan',
#  'https://t.co/xlBp1u27Fp',
#  'https://www.twitter.com/WRALSportsFan',
#  'https://t.co/GpI3h3Oa4r',
#  'https://www.twitter.com/WRALSportsFan',
#  'https://twitter.com/joeovies',
#  'https://twitter.com/lebrownlow',
#  'https://www.twitter.com/WRALSportsFan',
#  'https://t.co/gBryF2Nj02',
#  'https://www.twitter.com/WRALSportsFan',
#  'https://t.co/SjHSsP2tZr',
#  'https://www.twitter.com/WRALSportsFan',
#  'https://twitter.com/joeovies',
#  'https://twitter.com/lebrownlow',
#  'https://www.twitter.com/WRALSportsFan',
#  'https://twitter.com/joeovies',
#  'https://twitter.com/lebrownlow',
#  'https://www.twitter.com/WRALSportsFan',
#  'https://t.co/Dj6DQI1ZqN',
#  'https://www.twitter.com/WRALSportsFan',
#  'https://t.co/8zE3i6A1xv',
#  'https://www.twitter.com/WRALSportsFan',
#  'https://twitter.com/joeovies',
#  'https://t.co/9uAV1AY8lO',
#  'https://www.twitter.com/WRALSportsFan',
#  'https://twitter.com/joeovies',
#  'https://www.twitter.com/WRALSportsFan',
#  'https://twitter.com/joeovies',
#  'https://twitter.com/lebrownlow',
#  'https://www.twitter.com/WRALSportsFan',
#  'https://t.co/NHxX74364D',
#  'https://wral5.secondstreetapp.com/Can-You-Pass-the-Hardest-Super-Bowl-Trivia-Quiz/questions/2482327?allow-full-viewport=true',
#  'https://www.highschoolot.com/highschoolot-s-2020-boys-girls-basketball-playoff-projections/18901120/',
#  'https://www.highschoolot.com/highschoolot-s-2020-boys-girls-basketball-playoff-projections/18901120/',
#  'https://www.wral.com/greensboro-serving-again-this-week-as-center-of-figure-skating-world/18903588/',
#  'https://www.wral.com/greensboro-serving-again-this-week-as-center-of-figure-skating-world/18903588/',
#  'https://wral5.secondstreetapp.com/Can-You-Pass-the-Hardest-Super-Bowl-Trivia-Quiz/questions/2482327?allow-full-viewport=true',
#  'https://www.highschoolot.com/highschoolot-s-2020-boys-girls-basketball-playoff-projections/18901120/',
#  'https://www.highschoolot.com/highschoolot-s-2020-boys-girls-basketball-playoff-projections/18901120/',
#  'https://www.wral.com/greensboro-serving-again-this-week-as-center-of-figure-skating-world/18903588/',
#  'https://www.wral.com/greensboro-serving-again-this-week-as-center-of-figure-skating-world/18903588/',
#  'http://www.wral.com/wral-tv/aboutus/',
#  'https://wral.zendesk.com/hc/en-us',
#  'http://www.wral.com/wral-tv/page/1007423/',
#  'http://www.wraldigitalsolutions.com',
#  'http://www.wral.com/wral-digital-solutions/14995341/',
#  'http://www.aboutads.info/choices/',
#  'http://www.wral.com/wral-tv/page/5787234/',
#  'http://www.wral.com/rs/page/14295546/',
#  'http://cbc-raleigh.com/terms_use.asp',
#  'http://www.capitolbroadcasting.com/fcc-reports-2018-raleigh/',
#  'https://www.wral.com/fcc-public-inspection-file/18195139/',
#  'http://www.wral.com/wral-tv/aboutus/page/7249189/',
#  'http://www.wral.com/entertainment/contests/',
#  'https://www.facebook.com/999thefan',
#  'https://twitter.com/WRALSportsFan',
#  'https://sportsdata.io/']
